# %%
import pandas as pd
df =pd.read_csv('data.csv')

# %%
df.isnull().sum()
df.dropna(axis=0,inplace=True)

# %%
df.describe()
# Out:
#        Season Competition     Matchday      Date Venue         Club  \
# count     425         425          425       425   425          425
# unique     21          13           47       311     2            5
# top     14/15      LaLiga  Group Stage  04-05-15     H  Real Madrid
# freq       44         200           49         4   240          301
#
#           Opponent Result Playing_Position Minute At_score               Type  \
# count          425    425              425    425      425                425
# unique         103     51                5    101       38                  8
# top     Sevilla FC   3:00               LW     90     1:00  Right-footed shot
# freq            19     31              238     10       68                210
#
#           Goal_assist
# count             425
# unique             83
# top     Karim Benzema
# freq               44

# %%
df['Type'].unique()
# Out:
# array(['Header', 'Left-footed shot', 'Tap-in', 'Right-footed shot',
#        'Long distance kick', 'Counter attack goal',
#        'Deflected shot on goal', 'Penalty'], dtype=object)

# %%
df['Competition'].value_counts()
# Out:
# Competition
# LaLiga                   200
# UEFA Champions League    102
# Serie A                   48
# Premier League            37
# Copa del Rey              15
# FIFA Club World Cup        5
# Saudi Pro League           5
# FA Cup                     4
# Supercopa                  4
# UEFA Super Cup             2
# Liga Portugal              1
# Supercoppa Italiana        1
# Italy Cup                  1
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#    Season     Competition     Matchday      Date Venue               Club  \
# 1   02/03   Liga Portugal            6  10-07-02     H        Sporting CP
# 10  03/04          FA Cup        Final   5/22/04     H  Manchester United
# 14  04/05  Premier League           25  02-01-05     A  Manchester United
# 15  04/05  Premier League           25  02-01-05     A  Manchester United
# 19  04/05          FA Cup  Semi-Finals   4/17/05     A  Manchester United
#
#             Opponent Result Playing_Position Minute At_score  \
# 1      Moreirense FC   3:00               LW   90+5     3:00
# 10       Millwall FC   3:00               RW     44     1:00
# 14        Arsenal FC   2:04               RW     54     2:02
# 15        Arsenal FC   2:04               RW     58     2:03
# 19  Newcastle United   1:04               RW     76     1:04
#
#                  Type          Goal_assist
# 1              Header            Rui Jorge
# 10             Header         Gary Neville
# ...
